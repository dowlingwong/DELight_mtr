# %%
import json
import os
import shutil
from datetime import datetime, timedelta

import numpy as np
import strax
from bson import json_util
from tqdm import tqdm
import lz4.frame as lz4

import helix as hx
from helix import units
import strax as sx                    
import numba
import pandas as pd
import scipy as sp
import sys
import os
import shutil
from glob import glob
from matplotlib import pyplot as plt

run_id = 'run10' 
duration = 10  # seconds
raw_data_dir = 'toy_data'  # to save the raw toy data
helix_data_dir = 'test_helix_data'  # to save the run metadata

# %%
context = sx.Context(storage=[sx.DataDirectory(helix_data_dir, provide_run_metadata=True), ],
                     register=[hx.MMCRecords,
                               hx.QPTriggers, hx.UVTriggers,
                               hx.Events, hx.NoiseEvents,
                               hx.NoisePSDs, hx.FitResults])    # all the plugins required for getting fit_results

# creating a dictionary of plugins' options that we want to modify. 
config = {'run_metadata_directory': helix_data_dir,      # for the hx.ToyDataRawRecords plugin
          'noise_events_random_seed': 0}  # for the hx.NoiseEvents plugin

context.set_config(config)
events = context.get_array(run_id, 'events')

raw_data = events['channel_data']
raw_data.shape
# Out:
# Loading events: |                  | 0.00 % [00:00<?], #1 (0.34 s). 384.0 MB/s
# (9, 50, 32768)

# %%
fit_results = context.get_array(run_id, 'fit_results')  # hx.FitResults plugin provides this data type
# Out:
# /Users/wongdowling/Documents/helix/helix/optimum_filter.py:95: UserWarning: A zero PSD was passed to the OF. Disabling noise deweighting.
#   warn('A zero PSD was passed to the OF. Disabling noise deweighting.')
# /Users/wongdowling/Documents/helix/helix/optimum_filter.py:95: UserWarning: A zero PSD was passed to the OF. Disabling noise deweighting.
#   warn('A zero PSD was passed to the OF. Disabling noise deweighting.')
# /Users/wongdowling/Documents/helix/helix/optimum_filter.py:373: UserWarning: A zero PSD was passed to the OF. Disabling noise deweighting.
#   warn('A zero PSD was passed to the OF. Disabling noise deweighting.')
# /Users/wongdowling/Documents/helix/helix/optimum_filter.py:373: UserWarning: A zero PSD was passed to the OF. Disabling noise deweighting.
#   warn('A zero PSD was passed to the OF. Disabling noise deweighting.')
# /Users/wongdowling/Documents/helix/helix/optimum_filter.py:373: UserWarning: A zero PSD was passed to the OF. Disabling noise deweighting.
#   warn('A zero PSD was passed to the OF. Disabling noise deweighting.')
# Exception during processing, closing savers and reraising
# Loading fit_results: |                                      | 0.00 % [00:01<?]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fit_results = context.get_array(run_id, 'fit_results')  # hx.FitResults plugin provides this data type
#
# File ~/opt/anaconda3/envs/hupdate/lib/python3.12/site-packages/strax/context.py:1799, in Context.get_array(self, run_id, targets, save, max_workers, **kwargs)
#    1795 else:
#    1796     source = self.get_iter(
#    1797         run_ids[0], targets, save=save, max_workers=max_workers, **kwargs
#    1798     )
# -> 1799     results = [x.data for x in source]
#    1801 results = np.concatenate(results)
#    1802 return results
#
# File ~/opt/anaconda3/envs/hupdate/lib/python3.12/site-packages/strax/context.py:1652, in Context.get_iter(self, run_id, targets, save, max_workers, time_range, seconds_range, time_within, time_selection, selection, keep_columns, drop_columns, allow_multiple, progress_bar, multi_run_progress_bar, chunk_number, processor, combining, **kwargs)
#    1644     generator.throw(
#    1645         OutsideException(
#    1646             "Terminating due to an exception originating from outside "
#    1647             "strax's get_iter (which we cannot retrieve)."
#    1648         )
#    1649     )
#    1651 except Exception as e:
# -> 1652     generator.throw(e)
#    1653     raise ValueError(f"Failed to process chunk {n_chunks}!")
#    1655 if not seen_a_chunk:
#
# File ~/opt/anaconda3/envs/hupdate/lib/python3.12/site-packages/strax/context.py:1619, in Context.get_iter(self, run_id, targets, save, max_workers, time_range, seconds_range, time_within, time_selection, selection, keep_columns, drop_columns, allow_multiple, progress_bar, multi_run_progress_bar, chunk_number, processor, combining, **kwargs)
#    1617 pbar.strax_print_time = time.perf_counter()
#    1618 pbar.mbs = []
# -> 1619 for n_chunks, result in enumerate(strax.continuity_check(generator), 1):
#    1620     seen_a_chunk = True
#    1621     if not isinstance(result, strax.Chunk):
#
# File ~/opt/anaconda3/envs/hupdate/lib/python3.12/site-packages/strax/chunk.py:363, in continuity_check(chunk_iter)
#     360 last_runid = None
#     362 last_subrun = {"run_id": None}
# --> 363 for chunk in chunk_iter:
#     364     if chunk.run_id != last_runid:
#     365         last_end = None
#
# File ~/opt/anaconda3/envs/hupdate/lib/python3.12/site-packages/strax/processors/single_thread.py:63, in SingleThreadProcessor.iter(self)
#      60 self.log.debug(f"Yielding {target}")
#      62 try:
# ---> 63     yield from final_generator
#      65 except Exception:
#      66     # Exception in one of the producers. Close savers (they will record
#      67     # the exception from sys.exc_info()) then reraise.
#      68     self.log.fatal(f"Exception during processing, closing savers and reraising")
#
# File ~/opt/anaconda3/envs/hupdate/lib/python3.12/site-packages/strax/processors/post_office.py:204, in PostOffice._read(self, topic, reader)
#     201 else:
#     202     try:
#     203         # We have to produce a new message
# --> 204         result = self._fetch_new(topic)
#     205     except StopIteration:
#     206         # Message actually won't come, exit the while loop.
#     207         # (The while condition wasn't triggered because
#     208         # the producer only just realized the topic is exhausted)
#     209         break
#
# File ~/opt/anaconda3/envs/hupdate/lib/python3.12/site-packages/strax/processors/post_office.py:247, in PostOffice._fetch_new(self, topic)
#     245     raise RuntimeError(f"No producer registered for {topic}")
#     246 try:
# --> 247     msg = next(self._producers[topic])
#     248 except StopIteration:
#     249     for sub_topic in self._multi_output_topics.get(topic, [topic]):
#
# File ~/Documents/helix/helix/plugins/event_rqs/fit_results.py:215, in FitResults.iter(self, iters, executor)
#     213             yield new_future
#     214         else:
# --> 215             yield from self._iter_compute(chunk_i=chunk_i, **inputs_merged)
#     217 except IterDone:
#     218     # Check all sources are exhausted.
#     219     # This is more than a check though -- it ensure the content of
#     220     # all sources are requested all the way (including the final
#     221     # Stopiteration), as required by lazy-mode processing requires
#     222     for d in iters.keys():
#
# File ~/opt/anaconda3/envs/hupdate/lib/python3.12/site-packages/strax/plugins/plugin.py:568, in Plugin._iter_compute(self, chunk_i, **inputs_merged)
#     566 def _iter_compute(self, chunk_i, **inputs_merged):
#     567     """Either yields or returns strax chunks from the input."""
# --> 568     yield self.do_compute(chunk_i=chunk_i, **inputs_merged)
#
# File ~/Documents/helix/helix/plugins/event_rqs/fit_results.py:268, in FitResults.do_compute(self, chunk_i, **kwargs)
#     266     kwargs["start"] = start
#     267     kwargs["end"] = end
# --> 268 result = self.compute(**kwargs)
#     270 return self._fix_output(result, start, end)
#
# File ~/Documents/helix/helix/plugins/event_rqs/fit_results.py:331, in FitResults.compute(self, noise_psds, events)
#     325 sum_of = hx.TwoTemplatesOptimumFilter(self.uv_template, self.qp_template,
#     326                                       psd['summed_channel_psds'][i], sampling_frequency,
#     327                                       self.allowed_fit_shifts, self.allowed_two_template_deltas)
#     329 # Fits of all the cases where the OF can be precalculated
#     330 # Submerged
# --> 331 submerged_channel_results = submerged_channel_of.fit(
#     332     events[event_mask]['channel_data'][:, submerged_mask, l:r])
#     333 for j, key in enumerate(['submerged_channel_uv_amplitude',
#     334                          'submerged_channel_uv_offset',
#     335                          'submerged_channel_fit_chi2']):  # the key order corresponds to OF.fit output order
#     336     results[key][event_mask] = submerged_channel_results[j]
#
# File ~/Documents/helix/helix/optimum_filter.py:211, in OptimumFilter.fit(self, traces, allowed_shifts)
#     198 def fit(self, traces, allowed_shifts=UNSPECIFIED):
#     199     """
#     200     Performs Optimum Filter fit to the traces with the template rolls within the specified range.
#     201     :param traces: array of traces to fit. If OF has N templates and/or N PSDs, traces can be:
#    (...)
#     209     samples.
#     210     """
# --> 211     self._check_traces_shape(traces)
#     212     allowed_shifts = self._get_allowed_shifts(allowed_shifts)
#     214     # if the traces dimensionality is more than 2, while the number of PSDs and templates is 1, we flatten the
#     215     # input array of traces. We will "unflatten" the results right before returning them
#
# File ~/Documents/helix/helix/optimum_filter.py:122, in OptimumFilter._check_traces_shape(self, traces)
#     117 """
#     118 Checks whether the traces shape correspond to the OF templates and PSDs
#     119 :param traces: array of traces to fit
#     120 """
#     121 if traces.shape[-1] != self._template.shape[-1]:
# --> 122     raise ValueError(
#     123         f'In the OF, traces length {(traces.shape[-1])} must be equal to the template length '
#     124         f'({self._template.shape[-1]}).')
#     126 if len(self._kernel_fft.shape) > 1 and len(traces.shape) > 1 and self._kernel_fft.shape[0] != traces.shape[-2]:
#     127     raise ValueError(
#     128         f'In OF with more than one PSD or template, the -2 axis of traces should be equal to the number of '
#     129         f'PSDs or templates. Number of PSDs is {self._noise_psd_unfolded.shape[0]}. Number of templates is '
#     130         f'{self._template.shape[0]}. The provided traces shape is {traces.shape}')
#
# ValueError: In the OF, traces length 0 must be equal to the template length (32768).

# %%
channels = hx.Channels(hx.DEFAULT_CHANNEL_MAP)

template_path = './plugins/event_rqs/default_templates.npy'

template = np.load(template_path, allow_pickle=True)


# change this to choose another event if the one below is a bad one by chance
i = 8

plt.figure(figsize=(28,16))
artificial_baselines = np.arange(len(channels)) * 300  # adding artificial baselines to each channel to separate the channels on the plot
plt.plot(events['channel_data'][i].T + artificial_baselines, lw=0.5, alpha=0.8, color='C0')  # plotting data in each channel

event = fit_results[i]

# plotting two-template fits in the vacuum channels
for i_vac, i_ch in enumerate(channels.indices_of_type(hx.ChannelType.SUBMERGED)):
    if i_vac != 0:
        continue 
    fit = event['submerged_channel_uv_amplitude'][i_vac] * np.roll(template, 0)
    x = np.arange(len(template))
    plt.plot(x, fit+artificial_baselines[i_ch], lw=1, alpha=0.8, color='C1')



plt.xlabel('Time (samples)')
plt.ylabel('Current (ADC units)')
plt.title(f'Apply MMC readout on silent traces')
plt.savefig('raw_traces_on_silent_plot.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 15
#      12 artificial_baselines = np.arange(len(channels)) * 300  # adding artificial baselines to each channel to separate the channels on the plot
#      13 plt.plot(events['channel_data'][i].T + artificial_baselines, lw=0.5, alpha=0.8, color='C0')  # plotting data in each channel
# ---> 15 event = fit_results[i]
#      17 # plotting two-template fits in the vacuum channels
#      18 for i_vac, i_ch in enumerate(channels.indices_of_type(hx.ChannelType.SUBMERGED)):
#
# NameError: name 'fit_results' is not defined
