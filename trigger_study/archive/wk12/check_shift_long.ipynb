# %%
import yaml
import numpy as np
import zstandard as zstd
import os
from OptimumFilter import *
from TraceSimulator import LongTraceSimulator
import matplotlib.pyplot as plt
from trace_IO import *
def read_yaml_to_dict(file_path):
    with open(file_path, 'r') as file:
        config_dict = yaml.safe_load(file)
    return config_dict
sampling_frequency = 3906250
vac_template = np.load("templates/vac_ch_template.npy")
sub_template = np.load("templates/sub_ch_template.npy")
noise_psd = np.load("../../templates/noise_psd_from_MMC.npy")
config = read_yaml_to_dict('/home/dwong/DELight_mtr/trigger_study/archive/wk11/config.yaml')
lts = LongTraceSimulator(config)
vac_of = OptimumFilter(vac_template, noise_psd, sampling_frequency)
sub_of = OptimumFilter(sub_template, noise_psd, sampling_frequency)

# %%
trace, idx= lts.generate(
            E=7000,
            x=-94, y=0, z=-1800,
            no_noise=False,
            type_recoil='ER',
            quantize=True,
            phonon_only=False
        )
trace = trace[0]
amps = []
chisqs = []
shifts = []
positions = []
significant_fits = []
channels = []
all_fit_results = []

# These are for plotting
sub_deltas = []
sub_chisqs = []
vac_deltas = []
vac_chisqs = []

for ch in range(54):
    if ch < 45:
        ampl, chisq, shift, position = sub_of.rolling_fit_with_shift(trace[ch], allowed_shift_range=[0, 32767])
    else:
        ampl, chisq, shift, position = vac_of.rolling_fit_with_shift(trace[ch], allowed_shift_range=[0, 32767])
    
    # Store raw arrays
    amps.append(ampl)
    chisqs.append(chisq)
    shifts.append(shift)
    positions.append(position)
    
    # Store per-channel fits for later analysis
    fit_results = [
        {'channel': ch, 'amplitude': a, 'shift': s, 'chisq': c, 'position': p}
        for a, s, c, p in zip(ampl, shift, chisq, position)
    ]
    all_fit_results.extend(fit_results)

    # Filter significant amplitudes
    for res in fit_results:
        if res['amplitude'] > 7.5:
            significant_fits.append(res)
            channels.append(ch)
            delta = (res['position']-idx) 
            if ch < 45:
                sub_deltas.append(delta)
                sub_chisqs.append(res['chisq'])
            else:
                vac_deltas.append(delta)
                vac_chisqs.append(res['chisq'])

# ---- Plot ----
plt.figure(figsize=(8, 6))
plt.scatter(sub_deltas, sub_chisqs, alpha=0.6, label='Sub channels', color='blue')
plt.scatter(vac_deltas, vac_chisqs, alpha=0.6, label='Vac channels', color='orange')
plt.xlabel("Position error |position - idx|")
plt.ylabel("Chi²")
plt.title("Chi² vs. Position Error (Amplitude > 7.5)")
plt.grid(True)
plt.legend()
plt.show()

# %%
print("=== Fits with |position - idx| > 5000 and amplitude > 4 ===")
for res in all_fit_results:
    pos_error = res['position'] - idx
    amp = res['amplitude']
    ch = res['channel']
    chisq = res['chisq']
    shift_val = res['shift']  # <- Extract the shift here

    if amp > 4:
        # Check if any other fit in the same channel (excluding this one) has amp > 4
        other_fits = [r for r in all_fit_results if r['channel'] == ch and r != res]
        has_other_significant = any(r['amplitude'] > 4 for r in other_fits)

        print(f"Channel {ch} | Amplitude: {amp:.2f}, Chi²: {chisq:.2f}, Error: {pos_error}, Shift: {shift_val}, Other fit passed?: {has_other_significant}")
# Out:
# === Fits with |position - idx| > 5000 and amplitude > 4 ===
# Channel 0 | Amplitude: 48.49, Chi²: 0.93, Error: -2, Shift: 16341, Other fit passed?: True
# Channel 0 | Amplitude: 16.24, Chi²: 0.91, Error: 13256, Shift: -3169, Other fit passed?: True
# Channel 2 | Amplitude: 69.37, Chi²: 0.96, Error: -11, Shift: 16332, Other fit passed?: True
# Channel 2 | Amplitude: 21.01, Chi²: 0.93, Error: 13251, Shift: -3174, Other fit passed?: True
# Channel 3 | Amplitude: 46.28, Chi²: 0.94, Error: -4, Shift: 16339, Other fit passed?: True
# Channel 3 | Amplitude: 14.91, Chi²: 0.91, Error: 13229, Shift: -3196, Other fit passed?: True
# Channel 4 | Amplitude: 51.97, Chi²: 0.94, Error: 1, Shift: 16344, Other fit passed?: True
# Channel 4 | Amplitude: 15.18, Chi²: 0.92, Error: 13259, Shift: -3166, Other fit passed?: True
# Channel 5 | Amplitude: 85.66, Chi²: 0.96, Error: -6, Shift: 16337, Other fit passed?: True
# Channel 5 | Amplitude: 29.08, Chi²: 0.94, Error: 13241, Shift: -3184, Other fit passed?: True
# Channel 7 | Amplitude: 6.02, Chi²: 0.87, Error: -32615, Shift: -16272, Other fit passed?: False
# Channel 9 | Amplitude: 4.32, Chi²: 0.90, Error: -32066, Shift: -15723, Other fit passed?: False
# Channel 10 | Amplitude: 7.34, Chi²: 0.89, Error: -17, Shift: 16326, Other fit passed?: True
# Channel 10 | Amplitude: 4.57, Chi²: 0.87, Error: 13244, Shift: -3181, Other fit passed?: True
# Channel 11 | Amplitude: 7.34, Chi²: 0.89, Error: -32692, Shift: -16349, Other fit passed?: False
# Channel 12 | Amplitude: 13.41, Chi²: 0.90, Error: 39, Shift: 16382, Other fit passed?: True
# Channel 12 | Amplitude: 5.87, Chi²: 0.89, Error: 13441, Shift: -2984, Other fit passed?: True
# Channel 14 | Amplitude: 35.35, Chi²: 0.96, Error: -28204, Shift: -11861, Other fit passed?: True
# Channel 14 | Amplitude: 22.42, Chi²: 0.93, Error: 13219, Shift: -3206, Other fit passed?: True
# Channel 16 | Amplitude: 4.23, Chi²: 0.87, Error: -542, Shift: 15801, Other fit passed?: False
# Channel 17 | Amplitude: 47.03, Chi²: 0.93, Error: -9, Shift: 16334, Other fit passed?: True
# Channel 17 | Amplitude: 15.37, Chi²: 0.91, Error: 13231, Shift: -3194, Other fit passed?: True
# Channel 18 | Amplitude: 61.53, Chi²: 0.96, Error: 13, Shift: 16356, Other fit passed?: True
# Channel 18 | Amplitude: 20.37, Chi²: 0.93, Error: 13237, Shift: -3188, Other fit passed?: True
# Channel 19 | Amplitude: 34.27, Chi²: 0.92, Error: 3, Shift: 16346, Other fit passed?: True
# Channel 19 | Amplitude: 9.89, Chi²: 0.91, Error: 13239, Shift: -3186, Other fit passed?: True
# Channel 20 | Amplitude: 4.24, Chi²: 0.87, Error: -32660, Shift: -16317, Other fit passed?: False
# Channel 21 | Amplitude: 76.24, Chi²: 0.94, Error: -3, Shift: 16340, Other fit passed?: True
# Channel 21 | Amplitude: 23.80, Chi²: 0.93, Error: 13255, Shift: -3170, Other fit passed?: True
# Channel 22 | Amplitude: 171.72, Chi²: 1.07, Error: 0, Shift: 16343, Other fit passed?: True
# Channel 22 | Amplitude: 58.22, Chi²: 0.96, Error: 13236, Shift: -3189, Other fit passed?: True
# Channel 23 | Amplitude: 211.61, Chi²: 1.13, Error: 1, Shift: 16344, Other fit passed?: True
# Channel 23 | Amplitude: 68.89, Chi²: 0.98, Error: 13243, Shift: -3182, Other fit passed?: True
# Channel 24 | Amplitude: 333.15, Chi²: 1.45, Error: 0, Shift: 16343, Other fit passed?: True
# Channel 24 | Amplitude: 108.84, Chi²: 1.05, Error: 13249, Shift: -3176, Other fit passed?: True
# Channel 25 | Amplitude: 60.38, Chi²: 0.95, Error: 1, Shift: 16344, Other fit passed?: True
# Channel 25 | Amplitude: 18.13, Chi²: 0.93, Error: 13342, Shift: -3083, Other fit passed?: True
# Channel 26 | Amplitude: 56.79, Chi²: 0.94, Error: -1, Shift: 16342, Other fit passed?: True
# Channel 26 | Amplitude: 17.89, Chi²: 0.93, Error: 13282, Shift: -3143, Other fit passed?: True
# Channel 27 | Amplitude: 4.53, Chi²: 0.88, Error: -206, Shift: 16137, Other fit passed?: False
# Channel 28 | Amplitude: 110.16, Chi²: 0.99, Error: 5, Shift: 16348, Other fit passed?: True
# Channel 28 | Amplitude: 35.91, Chi²: 0.95, Error: 13238, Shift: -3187, Other fit passed?: True
# Channel 29 | Amplitude: 34.26, Chi²: 0.91, Error: 12, Shift: 16355, Other fit passed?: True
# Channel 29 | Amplitude: 10.82, Chi²: 0.89, Error: 13252, Shift: -3173, Other fit passed?: True
# Channel 30 | Amplitude: 110.94, Chi²: 0.99, Error: 2, Shift: 16345, Other fit passed?: True
# Channel 30 | Amplitude: 35.28, Chi²: 0.93, Error: 13241, Shift: -3184, Other fit passed?: True
# Channel 31 | Amplitude: 7.10, Chi²: 0.89, Error: -32695, Shift: -16352, Other fit passed?: False
# Channel 32 | Amplitude: 161.21, Chi²: 1.06, Error: -4, Shift: 16339, Other fit passed?: True
# Channel 32 | Amplitude: 53.32, Chi²: 0.95, Error: 13230, Shift: -3195, Other fit passed?: True
# Channel 33 | Amplitude: 50.71, Chi²: 0.93, Error: -11, Shift: 16332, Other fit passed?: True
# Channel 33 | Amplitude: 16.94, Chi²: 0.90, Error: 13274, Shift: -3151, Other fit passed?: True
# Channel 34 | Amplitude: 81.36, Chi²: 0.95, Error: -1, Shift: 16342, Other fit passed?: True
# Channel 34 | Amplitude: 27.81, Chi²: 0.93, Error: 13213, Shift: -3212, Other fit passed?: True
# Channel 35 | Amplitude: 261.50, Chi²: 1.25, Error: -6, Shift: 16337, Other fit passed?: True
# Channel 35 | Amplitude: 86.75, Chi²: 1.01, Error: 13240, Shift: -3185, Other fit passed?: True
# Channel 36 | Amplitude: 351.67, Chi²: 1.50, Error: -1, Shift: 16342, Other fit passed?: True
# Channel 36 | Amplitude: 116.41, Chi²: 1.05, Error: 13240, Shift: -3185, Other fit passed?: True
# Channel 37 | Amplitude: 145.45, Chi²: 1.01, Error: -3, Shift: 16340, Other fit passed?: True
# Channel 37 | Amplitude: 46.70, Chi²: 0.95, Error: 13250, Shift: -3175, Other fit passed?: True
# Channel 38 | Amplitude: 85.31, Chi²: 0.97, Error: 4, Shift: 16347, Other fit passed?: True
# Channel 38 | Amplitude: 28.22, Chi²: 0.93, Error: 13227, Shift: -3198, Other fit passed?: True
# Channel 39 | Amplitude: 46.89, Chi²: 0.94, Error: -4, Shift: 16339, Other fit passed?: True
# Channel 39 | Amplitude: 14.69, Chi²: 0.90, Error: 13239, Shift: -3186, Other fit passed?: True
# Channel 40 | Amplitude: 45.13, Chi²: 0.93, Error: 1, Shift: 16344, Other fit passed?: True
# Channel 40 | Amplitude: 13.84, Chi²: 0.90, Error: 13288, Shift: -3137, Other fit passed?: True
# Channel 41 | Amplitude: 70.79, Chi²: 0.95, Error: -2, Shift: 16341, Other fit passed?: True
# Channel 41 | Amplitude: 22.06, Chi²: 0.92, Error: 13254, Shift: -3171, Other fit passed?: True
# Channel 42 | Amplitude: 72.55, Chi²: 0.95, Error: 2, Shift: 16345, Other fit passed?: True
# Channel 42 | Amplitude: 23.11, Chi²: 0.93, Error: 13208, Shift: -3217, Other fit passed?: True
# Channel 44 | Amplitude: 55.39, Chi²: 0.95, Error: 4, Shift: 16347, Other fit passed?: True
# Channel 44 | Amplitude: 17.09, Chi²: 0.90, Error: 13224, Shift: -3201, Other fit passed?: True
# Channel 45 | Amplitude: 35.83, Chi²: 1.02, Error: 7437, Shift: -8988, Other fit passed?: False
# Channel 46 | Amplitude: 17.62, Chi²: 0.95, Error: 7532, Shift: -8893, Other fit passed?: False
# Channel 47 | Amplitude: 14.15, Chi²: 0.94, Error: 7533, Shift: -8892, Other fit passed?: False
# Channel 48 | Amplitude: 43.15, Chi²: 1.06, Error: 7205, Shift: -9220, Other fit passed?: False
# Channel 49 | Amplitude: 65.21, Chi²: 1.26, Error: 7468, Shift: -8957, Other fit passed?: False
# Channel 50 | Amplitude: 152.61, Chi²: 2.82, Error: 6971, Shift: -9454, Other fit passed?: False
# Channel 51 | Amplitude: 60.63, Chi²: 1.18, Error: 7376, Shift: -9049, Other fit passed?: False
# Channel 52 | Amplitude: 18.54, Chi²: 0.96, Error: 7375, Shift: -9050, Other fit passed?: False
# Channel 53 | Amplitude: 19.76, Chi²: 0.96, Error: 7468, Shift: -8957, Other fit passed?: False

# %%
idx
# Out:
# 400131

# %%
plt.plot(trace[0])

# %%
ampl, chisq, shift, position = sub_of.rolling_fit_with_shift(trace[0])

# %%
import matplotlib.pyplot as plt

# Constants
segment_len = 32768
start_idx = 37 * segment_len
end_idx = 39 * segment_len  # includes index 37 and 38

# Slice the desired segment
segment = trace[0][start_idx:end_idx]

# Plot it
plt.figure(figsize=(12, 4))
plt.plot(segment)
plt.title("Trace[0] Segment: Sub-traces 37 and 38")
plt.xlabel("Sample Index")
plt.ylabel("Amplitude")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load template
sub_template = np.load("templates/sub_ch_template.npy")

# Run the fit
ampl, chisq, shift, position = sub_of.rolling_fit_with_shift(trace[0])

# Constants
segment_len = 32768
trace_data = trace[0]

for idx in [37, 38]:
    # Get fitting parameters
    A = ampl[idx]
    s = shift[idx]        # integer shift (can be positive or negative)
    pos = position[idx]   # absolute fit position (in full trace)

    # Extract raw data segment
    start = idx * segment_len
    end = start + segment_len
    data_segment = trace_data[start:end]

    # Shift template appropriately (zero-padding if needed)
    shifted_template = np.roll(sub_template, s)

    # If desired, you could zero out the parts that are invalid due to roll
    # For example:
    # if s > 0:
    #     shifted_template[:s] = 0
    # elif s < 0:
    #     shifted_template[s:] = 0

    # Scale template
    fitted_template = A * shifted_template

    # Plot
    plt.figure(figsize=(12, 4))
    plt.plot(data_segment, label='Trace Segment')
    plt.plot(fitted_template, label=f'Fitted Template (A={A:.2f}, shift={s}, pos={pos})')
    plt.title(f"Template Fit for Segment {idx}")
    plt.xlabel("Sample Index (within segment)")
    plt.ylabel("Amplitude")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
